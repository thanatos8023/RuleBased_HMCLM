# %%
target_syl = {
    'Control_Engine_Start': [
        {
            ('시동', 'NNG'),
            ('공조', 'NNG'),
            ('에어컨', 'NNG'),
            ('히터', 'NNG'),
            ('온도', 'NNG')
        },
        {
            ('켜', 'VV'),
            ('걸', 'VV'),
            ('켜', 'VV+EC'),
            ('맞춰', 'VV+EC'),
            ('맞춰라', 'VV+EC'),
            ('맞춰요', 'VV+EF'),
            ('걸어라', 'VV+EC'),
            ('맞', 'VV'),
            ('설정', 'NNG'),
            ('조절', 'NNG'),
            ('온', 'NNG'),
            ('온', 'VV+ETM'),
            ('on', 'SL')
        }
    ],
    'Control_Engine_Stop': [
        {
            ('시동', 'NNG'),
            ('공조', 'NNG'),
            ('에어컨', 'NNG'),
            ('히터', 'NNG'),
            ('차', 'NNG')
        },
        {
            ('꺼', 'VV+EC'),
            ('끄', 'VV'),
            ('꺼라', 'VV+EC'),
            ('꺼', 'VV'),
            ('꺼', 'NNB+VCP'),
            ('오프', 'NNG'),
            ('off', 'SL')
        }
    ],
    'Control_Door_Open': [
        {
            ('문', 'NNG'),
            ('차문', 'NNG'),
            ('도어', 'NNG'),
            ('어', 'IC')
        },
        {
            ('열', 'VV')
        }
    ],
    'Control_Door_Close': [
        {
            ('문', 'NNG'),
            ('차문', 'NNG'),
            ('도어', 'NNG'),
            ('어', 'IC')
        },
        {
            ('닫', 'VV'),
            ('잠궈', 'VV+EC')
        }
    ],
    'Control_Horn_On': [
        {
            ('경적', 'NNG'),
            ('크락', 'NNP'),
            ('션', 'NNG'),
            ('션', 'NNP')
        }
    ],
    'Control_Light_On': [
        {
            ('깜빡이', 'NNG'),
            ('비상', 'NNG'),
            ('등', 'NNB')
        }
    ],
    'Control_Charge_Start': [
        {
            ('충전', 'NNG')
        }
    ],
    'Control_Charge_Stop': [
        {
            ('충전', 'NNG')
        },
        {
            ('멈춰', 'VV+EC'),
            ('그만', 'MAG'),
            ('그만', 'XR'),
            ('종료', 'NNG'),
            ('중지', 'NNG'),
        },
    ],
    'Help_AirCon': [
        {
            ('에어컨', 'NNG'),
            ('에어', 'NNP'),
            ('콘', 'NNG')
        },
        {
            ('냄새', 'NNG')
        },
    ],
    'Help_Can': [
        {
            ('할', 'VV+ETM')
        },
        {
            ('수', 'NNB'),
            ('줄', 'NNB')
        },
    ],
    'Help_Conversation': [
        {
            ('상담', 'NNG')
        }
    ],
    'Help_EngineOil': [
        {
            ('엔진오일', 'NNP'),
            ('엔진', 'NNG'),
            ('오', 'NR'),
            ('일', 'NNBC')
        },
        {
            ('교체', 'NNG'),
            ('교환', 'NNG'),
            ('갈', 'VV'),
            ('갈지', 'VV+EC'),
            ('갈', 'VV+ETM')
        },
        {
            ('주기', 'NNG'),
            ('언제', 'MAG'),
            ('때', 'NNG'),
        }
    ],
    'Help_OnlyQuestion': [
        {
            ('이상', 'NNG')
        }
    ],
    'Help_Repair': [
        {
            ('정비', 'NNG'),
            ('핸즈', 'NNP')
        }
    ],

    'SmallTalk_AgeRU': [
        {
            ('살', 'NNBC'),
            ('짤', 'VV+ETM')
        }
    ],
    'SmallTalk_Bye': [
        {
            ('바이', 'NNG'),
            ('갈게', 'VV+EC'),
            ('빠이', 'IC'),
            ('가', 'VV+EC'),
        }
    ],
    'SmallTalk_DoingWhat': [
        {
            ('뭐', 'IC'),
            ('머', 'NP'),
        },
        {
            ('해', 'VV+EC'),
            ('해', 'VV+EF'),
            ('있', 'VX'),
            ('냐', 'EF'),
            ('냐', 'EC')
        }
    ],
    #'SmallTalk_Emoticon': {
    #    'Necessary': [
    #    ],
    #    'Special': {}
    #},
    'SmallTalk_Fun': [
        {
            ('얘기', 'NNG'),
            ('유머', 'NNG'),
            ('이야기', 'NNG'),
            ('재밌', 'VA'),
            ('재미있', 'VA'),
            ('웃겨', 'VV+EC'),
            ('웃기', 'VV')
        }
    ],
    #'SmallTalk_Fword': {},
    'SmallTalk_Gloomy': [
        {
            ('우울', 'NNG'),
            ('울적', 'NNG'),
            ('슬퍼', 'VA+EC')
        }
    ],
    'SmallTalk_Hello': [
        {
            ('안녕', 'NNG'),
            ('하이', 'NNG'),
            ('헬로', 'NNP'),
            ('방가', 'NNG'),
            ('안녕', 'IC'),
            ('뇽', 'UNKNOWN'),
            ('반가워', 'VA+EC'),
            ('헬로우', 'IC'),
            ('hi', 'SL'),
            ('hello', 'SL')
        }
    ],
    'SmallTalk_Hungry': [
        {
            ('배고파', 'VA+EC'),
            ('배고프', 'VA'),
            ('출출', 'XR')
        }
    ],
    'SmallTalk_LetsPlay': [
        {
            ('심심', 'NNG'),
            ('심심', 'XR'),
            ('놀', 'VV')
        }
    ],
    'SmallTalk_RUThere': [
        {
            ('여보세요', 'IC'),
        }
    ],
    'SmallTalk_Thanks': [
        {
            ('고마워', 'VA+EC'),
            ('기특', 'XR'),
            ('좋', 'VA'),
        }
    ],
    'SmallTalk_Tired': [
        {
            ('잠', 'NNG'),
            ('피곤', 'NNG'),
            ('지침', 'NNG'),
            ('졸려', 'VA+EC'),
            ('졸린다', 'VV+EC'),
            ('지쳐', 'VV+EC'),
            ('지쳤', 'VV+EP'),
            ('자', 'VV'),
            ('잠자', 'VV'),
            ('힘들', 'VA'),
        }
    ],
    'SmallTalk_WhoRU': [
        {
            ('누구', 'NP')
        }
    ],
}

# %%
from eunjeon import Mecab
import re
import json
import os
import glob
import pickle


class Model():
    def __init__(self, req):
        self.mecab = Mecab()

        req_body = json.loads(req)

        self.utt = req_body['utt']
        self.code = req_body['code']
        self.user_key = req_body['user_key']

        self.pos = self.mecab.pos(self.utt)

        self.target_syl = target_syl

        # Kakao button inputs
        # Input message fixed.
        #self.buttons_response = pickle.load()

        # Responses for intentions or buttons to Chatbot api (Dictionary object)
        # key: intention
        # value: response object(json)
        # The response form is json

    def __get_intention__(self):
        intention = self.__get_intention_from_lm__()

        if intention:
            return intention
        else:
            return "Fail"

    def __get_intention_from_lm__(self):
        # Searching in intentions
        for key in self.target_syl:
            matched_case = 0
            for necset in self.target_syl[key]:
                # There are set of morphs
                # mached
                matched = necset & set(self.pos)
                if not matched:
                    break
                else:
                    matched_case += 1

            if matched_case == len(self.target_syl[key]):
                # This case, the utterance is in this intention
                return key

        return None

# %%
result = {
    'Success': [],
    'Fail': []
}

all_sents = 0

for fn in glob.glob('corpus/*.txt'):
    with open(fn, 'r', encoding='utf-8') as f:
        raw = f.read().split('\n')
        
    for sent in raw:
        req = {
            'utt': sent,
            'code': 7000,
            'user_key': 'asdfqew52'
        }
        
        m = Model(json.dumps(req))
        intention = m.__get_intention__()
        
        if intention == 'Fail':
            result['Fail'].append((fn, sent))
        else:
            result['Success'].append((intention, sent))
            
        all_sents += len(raw)
    
print('Error rate: %f' % (len(result['Fail']) / all_sents))
print()
print('--- Error cases')
for fail in result['Fail']:
    print(fail)
# Out:
# Error rate: 0.000065
#
# --- Error cases
# ('corpus\\Control_Engine_Start_autoTemp.txt', '아무거나')
# ('corpus\\Control_Engine_Start_autoTemp.txt', '대충')
# ('corpus\\Control_Engine_Start_autoTemp.txt', '몰라')
# ('corpus\\Control_Engine_Start_autoTemp.txt', '걍해')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷ')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷㄱㄱ')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동라')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷ')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷㄱㄱ')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동요')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷ')
# ('corpus\\Control_Engine_Start_noTemp.txt', 'ㅅㄷㄱㄱ')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동 좀 온요')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동 좀온요')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동좀 온요')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동을 온요')
# ('corpus\\Control_Engine_Start_noTemp.txt', '시동 온요')
# ('corpus\\Control_Engine_Stop.txt', '꺼')
# ('corpus\\Control_Engine_Stop.txt', '내 차 시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내차 시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '꺼라')
# ('corpus\\Control_Engine_Stop.txt', '시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내차 에어컨 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내차 히터 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내차 시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내 차 에어컨 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내 차 히터 오프라')
# ('corpus\\Control_Engine_Stop.txt', '내 차 시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '에어컨 오프라')
# ('corpus\\Control_Engine_Stop.txt', '히터 오프라')
# ('corpus\\Control_Engine_Stop.txt', '시동 오프라')
# ('corpus\\Control_Engine_Stop.txt', '꺼요')
# ('corpus\\Control_Only_Temp.txt', '15')
# ('corpus\\Control_Only_Temp.txt', '16')
# ('corpus\\Control_Only_Temp.txt', '17')
# ('corpus\\Control_Only_Temp.txt', '18')
# ('corpus\\Control_Only_Temp.txt', '19')
# ('corpus\\Control_Only_Temp.txt', '20')
# ('corpus\\Control_Only_Temp.txt', '21')
# ('corpus\\Control_Only_Temp.txt', '22')
# ('corpus\\Control_Only_Temp.txt', '23')
# ('corpus\\Control_Only_Temp.txt', '24')
# ('corpus\\Control_Only_Temp.txt', '25')
# ('corpus\\Control_Only_Temp.txt', '26')
# ('corpus\\Control_Only_Temp.txt', '27')
# ('corpus\\Control_Only_Temp.txt', '28')
# ('corpus\\Control_Only_Temp.txt', '29')
# ('corpus\\Control_Only_Temp.txt', '30')
# ('corpus\\Control_Only_Temp.txt', '31')
# ('corpus\\Control_Only_Temp.txt', '32')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '15 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '15 도')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '15 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '15 도로')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '16 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '16 도')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '16 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '16 도로')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '17 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '17 도')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '17 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '17 도로')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '18 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '18 도')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '18 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '18 도로')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '19 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '19 도')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '19 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '19 도로')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '20 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '20 도')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '20 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '20 도로')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '21 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '21 도')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '21 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '21 도로')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '22 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '22 도')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '22 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '22 도로')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '23 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '23 도')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '23 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '23 도로')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '24 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '24 도')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '24 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '24 도로')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '25 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '25 도')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '25 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '25 도로')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '26 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '26 도')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '26 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '26 도로')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '27 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '27 도')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '27 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '27 도로')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '28 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '28 도')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '28 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '28 도로')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '29 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '29 도')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '29 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '29 도로')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '30 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '30 도')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '30 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '30 도로')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '31 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '31 도')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '31 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '31 도로')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '32 도 해줘')
# ('corpus\\Control_Only_Temp.txt', '32 도')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '32 도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '32 도로')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '15도 해줘')
# ('corpus\\Control_Only_Temp.txt', '15도')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '15도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '15도로')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '16도 해줘')
# ('corpus\\Control_Only_Temp.txt', '16도')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '16도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '16도로')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '17도 해줘')
# ('corpus\\Control_Only_Temp.txt', '17도')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '17도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '17도로')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '18도 해줘')
# ('corpus\\Control_Only_Temp.txt', '18도')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '18도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '18도로')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '19도 해줘')
# ('corpus\\Control_Only_Temp.txt', '19도')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '19도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '19도로')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '20도 해줘')
# ('corpus\\Control_Only_Temp.txt', '20도')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '20도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '20도로')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '21도 해줘')
# ('corpus\\Control_Only_Temp.txt', '21도')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '21도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '21도로')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '22도 해줘')
# ('corpus\\Control_Only_Temp.txt', '22도')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '22도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '22도로')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '23도 해줘')
# ('corpus\\Control_Only_Temp.txt', '23도')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '23도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '23도로')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '24도 해줘')
# ('corpus\\Control_Only_Temp.txt', '24도')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '24도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '24도로')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '25도 해줘')
# ('corpus\\Control_Only_Temp.txt', '25도')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '25도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '25도로')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '26도 해줘')
# ('corpus\\Control_Only_Temp.txt', '26도')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '26도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '26도로')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '27도 해줘')
# ('corpus\\Control_Only_Temp.txt', '27도')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '27도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '27도로')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '28도 해줘')
# ('corpus\\Control_Only_Temp.txt', '28도')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '28도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '28도로')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '29도 해줘')
# ('corpus\\Control_Only_Temp.txt', '29도')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '29도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '29도로')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '30도 해줘')
# ('corpus\\Control_Only_Temp.txt', '30도')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '30도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '30도로')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '31도 해줘')
# ('corpus\\Control_Only_Temp.txt', '31도')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '31도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '31도로')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰')
# ('corpus\\Control_Only_Temp.txt', '32도 해줘')
# ('corpus\\Control_Only_Temp.txt', '32도')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰줘')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰')
# ('corpus\\Control_Only_Temp.txt', '32도로 해줘')
# ('corpus\\Control_Only_Temp.txt', '32도로')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '15 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '15 도라')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '15 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '15 도로라')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '16 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '16 도라')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '16 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '16 도로라')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '17 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '17 도라')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '17 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '17 도로라')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '18 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '18 도라')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '18 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '18 도로라')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '19 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '19 도라')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '19 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '19 도로라')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '20 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '20 도라')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '20 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '20 도로라')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '21 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '21 도라')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '21 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '21 도로라')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '22 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '22 도라')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '22 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '22 도로라')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '23 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '23 도라')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '23 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '23 도로라')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '24 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '24 도라')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '24 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '24 도로라')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '25 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '25 도라')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '25 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '25 도로라')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '26 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '26 도라')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '26 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '26 도로라')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '27 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '27 도라')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '27 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '27 도로라')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '28 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '28 도라')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '28 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '28 도로라')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '29 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '29 도라')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '29 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '29 도로라')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '30 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '30 도라')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '30 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '30 도로라')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '31 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '31 도라')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '31 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '31 도로라')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '32 도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '32 도라')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '32 도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '32 도로라')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '15도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '15도라')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '15도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '15도로라')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '16도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '16도라')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '16도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '16도로라')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '17도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '17도라')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '17도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '17도로라')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '18도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '18도라')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '18도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '18도로라')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '19도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '19도라')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '19도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '19도로라')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '20도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '20도라')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '20도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '20도로라')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '21도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '21도라')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '21도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '21도로라')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '22도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '22도라')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '22도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '22도로라')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '23도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '23도라')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '23도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '23도로라')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '24도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '24도라')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '24도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '24도로라')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '25도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '25도라')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '25도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '25도로라')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '26도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '26도라')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '26도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '26도로라')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '27도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '27도라')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '27도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '27도로라')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '28도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '28도라')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '28도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '28도로라')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '29도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '29도라')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '29도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '29도로라')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '30도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '30도라')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '30도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '30도로라')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '31도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '31도라')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '31도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '31도로라')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '32도 해줘라')
# ('corpus\\Control_Only_Temp.txt', '32도라')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰줘라')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰라')
# ('corpus\\Control_Only_Temp.txt', '32도로 해줘라')
# ('corpus\\Control_Only_Temp.txt', '32도로라')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '15 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '15 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '15 도요')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '15 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '15 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '15 도로요')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '16 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '16 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '16 도요')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '16 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '16 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '16 도로요')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '17 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '17 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '17 도요')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '17 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '17 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '17 도로요')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '18 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '18 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '18 도요')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '18 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '18 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '18 도로요')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '19 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '19 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '19 도요')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '19 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '19 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '19 도로요')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '20 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '20 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '20 도요')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '20 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '20 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '20 도로요')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '21 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '21 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '21 도요')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '21 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '21 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '21 도로요')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '22 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '22 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '22 도요')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '22 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '22 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '22 도로요')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '23 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '23 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '23 도요')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '23 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '23 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '23 도로요')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '24 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '24 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '24 도요')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '24 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '24 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '24 도로요')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '25 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '25 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '25 도요')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '25 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '25 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '25 도로요')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '26 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '26 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '26 도요')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '26 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '26 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '26 도로요')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '27 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '27 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '27 도요')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '27 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '27 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '27 도로요')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '28 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '28 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '28 도요')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '28 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '28 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '28 도로요')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '29 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '29 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '29 도요')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '29 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '29 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '29 도로요')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '30 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '30 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '30 도요')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '30 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '30 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '30 도로요')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '31 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '31 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '31 도요')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '31 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '31 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '31 도로요')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '32 도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '32 도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '32 도요')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '32 도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '32 도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '32 도로요')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '15도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '15도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '15도요')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '15도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '15도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '15도로요')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '16도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '16도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '16도요')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '16도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '16도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '16도로요')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '17도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '17도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '17도요')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '17도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '17도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '17도로요')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '18도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '18도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '18도요')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '18도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '18도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '18도로요')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '19도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '19도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '19도요')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '19도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '19도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '19도로요')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '20도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '20도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '20도요')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '20도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '20도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '20도로요')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '21도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '21도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '21도요')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '21도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '21도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '21도로요')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '22도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '22도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '22도요')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '22도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '22도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '22도로요')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '23도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '23도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '23도요')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '23도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '23도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '23도로요')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '24도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '24도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '24도요')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '24도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '24도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '24도로요')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '25도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '25도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '25도요')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '25도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '25도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '25도로요')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '26도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '26도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '26도요')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '26도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '26도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '26도로요')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '27도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '27도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '27도요')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '27도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '27도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '27도로요')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '28도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '28도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '28도요')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '28도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '28도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '28도로요')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '29도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '29도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '29도요')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '29도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '29도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '29도로요')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '30도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '30도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '30도요')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '30도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '30도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '30도로요')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '31도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '31도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '31도요')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '31도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '31도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '31도로요')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '32도 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '32도 해줘요')
# ('corpus\\Control_Only_Temp.txt', '32도요')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰줘요')
# ('corpus\\Control_Only_Temp.txt', '32도로 맞춰요')
# ('corpus\\Control_Only_Temp.txt', '32도로 해줘요')
# ('corpus\\Control_Only_Temp.txt', '32도로요')
# ('corpus\\FAQ_Call.txt', '블루링크 전화번호는 어디서 확인하나요')
# ('corpus\\FAQ_Call.txt', '블루링크 전화번호는 어떻게 확인해')
# ('corpus\\FAQ_Call.txt', '블루링크 전화번호를 확인하고 싶어')
# ('corpus\\FAQ_Call.txt', '차량 전화번호는 어디서 확인해')
# ('corpus\\FAQ_Call.txt', '차량 전화번호는 어떻게 확인해')
# ('corpus\\FAQ_Call.txt', '차량 전화번호를 확인하고 싶어')
# ('corpus\\FAQ_Call.txt', '블루링크 전화번호 확인')
# ('corpus\\FAQ_Call.txt', '블루링크 전화번호')
# ('corpus\\FAQ_Call.txt', '차량 전화번호')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 서비스는 어떻게 이용하나요')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지서비스는 어떻게 이용하나요')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지는 어떻게 이용해')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 서비스 이용 방법')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 이용 방법')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 이용방법')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 서비스는 뭐야')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지서비스는 뭐야')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 서비스는 어떻게 쓰지')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지서비스는 어떻게 쓰지')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지 서비스는 어떻게 써')
# ('corpus\\FAQ_Conciousy.txt', '컨시어지서비스는 어떻게 써')
# ('corpus\\FAQ_CryaneAccount.txt', '긴급 견인 출동 요원이 견인을 하면서 특수 장비가 필요한 경우 추가 비용이 드나요')
# ('corpus\\FAQ_CryaneAccount.txt', '견인시 특수 장비 추가 비용은')
# ('corpus\\FAQ_CryaneAccount.txt', '견인 시 특수장비 추가비용은')
# ('corpus\\FAQ_CryaneAccount.txt', '견인시 특수장비 추가비용은')
# ('corpus\\FAQ_CryaneAccount.txt', '견인 때 특수장비 사용하면 추가비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인 때 특수 장비 사용하면 추가 비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인때 특수장비 사용하면 추가비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인때 특수 장비 사용하면 추가 비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인할 때 특수장비 사용하면 추가비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인할 때 특수 장비 사용하면 추가 비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인할때 특수장비 사용하면 추가비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '견인할때 특수 장비 사용하면 추가 비용 들어')
# ('corpus\\FAQ_CryaneAccount.txt', '특수장비로 견인하면 추가 비용 드나')
# ('corpus\\FAQ_CryaneAccount.txt', '특수 장비로 견인하면 추가 비용 드나')
# ('corpus\\FAQ_CryaneAccount.txt', '특수장비로 견인하면 추가비용 드나')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지할래')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지해줘')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지할래')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지해줘')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지할래')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지해줘')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 하고 싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지하고싶어')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지할래')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지해줘')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 방법')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지할래요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지해줘요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 좀 해지 방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지할래요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지해줘요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크 해지 방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지할래요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지해줘요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 좀 해지 방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 하고 싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지하고싶어요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지할래요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지해줘요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지 방법요')
# ('corpus\\FAQ_Dismiss.txt', '블루링크를 해지하려면 어떻게 해야 하나요')
# ('corpus\\FAQ_DrivingControlError.txt', '주행 중에 시스템 조작이 안돼요')
# ('corpus\\FAQ_DrivingControlError.txt', '주행 중 시스템 조작 불가')
# ('corpus\\FAQ_DrivingControlError.txt', '주행중 시스템 조작불가')
# ('corpus\\FAQ_DrivingControlError.txt', '주행중 시스템 조작이 왜 안돼')
# ('corpus\\FAQ_DrivingControlError.txt', '주행 중 시스템을 움직이는 게 왜 안될까')
# ('corpus\\FAQ_DrivingControlError.txt', '주행하는데 시스템 조작 안돼')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급 출동으로 시동 걸 때 추가비용 들어')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급출동으로 시동걸 때 추가비용 들어')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급 출동으로 시동 걸 때 추가 비용 들어')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급 출동으로 시동 켤 때 추가 비용 들까')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급출동으로 시동켤 때 추가비용 들까')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급출동으로 시동켤때 추가비용 들까')
# ('corpus\\FAQ_EmergencyAccount.txt', '긴급출동으로 시동켤때 추가 비용 들까')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유가 떨어진 경우에도 긴급 주유 서비스가 제공되나요')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유가 떨어진 경우에도 긴급주유서비스가 제공되나요')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유 없으면 긴급주유 할 수 있어')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유 없으면 긴급주유할 수 있어')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유 없으면 긴급주유 할수있어')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유 없으면 긴급주유 할수 있어')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유가 없으면 긴급 주유 서비스 가능해')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유가 없으면 긴급주유서비스 가능해')
# ('corpus\\FAQ_EmergencyGas.txt', '자동차전용도로에서 휘발유가 없으면 긴급주유 가능해')
# ...
# ('corpus\\SmallTalk_Fword.txt', 'ㄱㅐ')
# ('corpus\\SmallTalk_Fword.txt', 'ㄲㅏ')
# ('corpus\\SmallTalk_Fword.txt', 'ㄲㅑ')
# ('corpus\\SmallTalk_Fword.txt', 'ㄲㅣ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅅㅂㄹㅁ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅅㅐ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅆㅂㄹㅁ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅆㅍ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅆㅣ')
# ('corpus\\SmallTalk_Fword.txt', 'ㅆ앙')
# ('corpus\\SmallTalk_Fword.txt', 'ㅍㅏ')
# ('corpus\\SmallTalk_Fword.txt', '凸')
# ('corpus\\SmallTalk_Fword.txt', '갈보년')
# ('corpus\\SmallTalk_Fword.txt', '같은년')
# ('corpus\\SmallTalk_Fword.txt', '같은뇬')
# ('corpus\\SmallTalk_Fword.txt', '개같은')
# ('corpus\\SmallTalk_Fword.txt', '개구라')
# ('corpus\\SmallTalk_Fword.txt', '개뇬')
# ('corpus\\SmallTalk_Fword.txt', '개대중')
# ('corpus\\SmallTalk_Fword.txt', '개독')
# ('corpus\\SmallTalk_Fword.txt', '개돼중')
# ('corpus\\SmallTalk_Fword.txt', '개랄')
# ('corpus\\SmallTalk_Fword.txt', '개보지')
# ('corpus\\SmallTalk_Fword.txt', '개뻥')
# ('corpus\\SmallTalk_Fword.txt', '개뿔')
# ('corpus\\SmallTalk_Fword.txt', '개새')
# ('corpus\\SmallTalk_Fword.txt', '개새기')
# ('corpus\\SmallTalk_Fword.txt', '개새키')
# ('corpus\\SmallTalk_Fword.txt', '개색기')
# ('corpus\\SmallTalk_Fword.txt', '개색끼')
# ('corpus\\SmallTalk_Fword.txt', '개색키')
# ('corpus\\SmallTalk_Fword.txt', '개색히')
# ('corpus\\SmallTalk_Fword.txt', '개섀끼')
# ('corpus\\SmallTalk_Fword.txt', '개세')
# ('corpus\\SmallTalk_Fword.txt', '개세끼')
# ('corpus\\SmallTalk_Fword.txt', '개세이')
# ('corpus\\SmallTalk_Fword.txt', '개소리')
# ('corpus\\SmallTalk_Fword.txt', '개쑈')
# ('corpus\\SmallTalk_Fword.txt', '개쇳기')
# ('corpus\\SmallTalk_Fword.txt', '개수작')
# ('corpus\\SmallTalk_Fword.txt', '개쉐')
# ('corpus\\SmallTalk_Fword.txt', '개쉐리')
# ('corpus\\SmallTalk_Fword.txt', '개쉐이')
# ('corpus\\SmallTalk_Fword.txt', '개쉑')
# ('corpus\\SmallTalk_Fword.txt', '개쉽')
# ('corpus\\SmallTalk_Fword.txt', '개스끼')
# ('corpus\\SmallTalk_Fword.txt', '개시키')
# ('corpus\\SmallTalk_Fword.txt', '개십새기')
# ('corpus\\SmallTalk_Fword.txt', '개십새끼')
# ('corpus\\SmallTalk_Fword.txt', '개쐑')
# ('corpus\\SmallTalk_Fword.txt', '개씹')
# ('corpus\\SmallTalk_Fword.txt', '개아들')
# ('corpus\\SmallTalk_Fword.txt', '개자슥')
# ('corpus\\SmallTalk_Fword.txt', '개자지')
# ('corpus\\SmallTalk_Fword.txt', '개접')
# ('corpus\\SmallTalk_Fword.txt', '개좆')
# ('corpus\\SmallTalk_Fword.txt', '개좌식')
# ('corpus\\SmallTalk_Fword.txt', '개허접')
# ('corpus\\SmallTalk_Fword.txt', '걔새')
# ('corpus\\SmallTalk_Fword.txt', '걔수작')
# ('corpus\\SmallTalk_Fword.txt', '걔시끼')
# ('corpus\\SmallTalk_Fword.txt', '걔시키')
# ('corpus\\SmallTalk_Fword.txt', '걔썌')
# ('corpus\\SmallTalk_Fword.txt', '걸레')
# ('corpus\\SmallTalk_Fword.txt', '게색기')
# ('corpus\\SmallTalk_Fword.txt', '게색끼')
# ('corpus\\SmallTalk_Fword.txt', '광뇬')
# ('corpus\\SmallTalk_Fword.txt', '구녕')
# ('corpus\\SmallTalk_Fword.txt', '구라')
# ('corpus\\SmallTalk_Fword.txt', '그년')
# ('corpus\\SmallTalk_Fword.txt', '그새끼')
# ('corpus\\SmallTalk_Fword.txt', '냄비')
# ('corpus\\SmallTalk_Fword.txt', '놈현')
# ('corpus\\SmallTalk_Fword.txt', '뇬')
# ('corpus\\SmallTalk_Fword.txt', '뉘미럴')
# ('corpus\\SmallTalk_Fword.txt', '니귀미')
# ('corpus\\SmallTalk_Fword.txt', '니기미')
# ('corpus\\SmallTalk_Fword.txt', '니미')
# ('corpus\\SmallTalk_Fword.txt', '니미랄')
# ('corpus\\SmallTalk_Fword.txt', '니미럴')
# ('corpus\\SmallTalk_Fword.txt', '니미씹')
# ('corpus\\SmallTalk_Fword.txt', '니아배')
# ('corpus\\SmallTalk_Fword.txt', '니아베')
# ('corpus\\SmallTalk_Fword.txt', '니아비')
# ('corpus\\SmallTalk_Fword.txt', '니어매')
# ('corpus\\SmallTalk_Fword.txt', '니어메')
# ('corpus\\SmallTalk_Fword.txt', '니어미')
# ('corpus\\SmallTalk_Fword.txt', '닝기리')
# ('corpus\\SmallTalk_Fword.txt', '닝기미')
# ('corpus\\SmallTalk_Fword.txt', '뎡신')
# ('corpus\\SmallTalk_Fword.txt', '도라이')
# ('corpus\\SmallTalk_Fword.txt', '돈놈')
# ('corpus\\SmallTalk_Fword.txt', '돌은놈')
# ('corpus\\SmallTalk_Fword.txt', '되질래')
# ('corpus\\SmallTalk_Fword.txt', '뒈져')
# ('corpus\\SmallTalk_Fword.txt', '뒈져라')
# ('corpus\\SmallTalk_Fword.txt', '뒈진')
# ('corpus\\SmallTalk_Fword.txt', '뒈진다')
# ('corpus\\SmallTalk_Fword.txt', '뒈질')
# ('corpus\\SmallTalk_Fword.txt', '뒤질래')
# ('corpus\\SmallTalk_Fword.txt', '디져라')
# ('corpus\\SmallTalk_Fword.txt', '디진다')
# ('corpus\\SmallTalk_Fword.txt', '디질래')
# ('corpus\\SmallTalk_Fword.txt', '딩시')
# ('corpus\\SmallTalk_Fword.txt', '따식')
# ('corpus\\SmallTalk_Fword.txt', '때놈')
# ('corpus\\SmallTalk_Fword.txt', '똘아이')
# ('corpus\\SmallTalk_Fword.txt', '뙈놈')
# ('corpus\\SmallTalk_Fword.txt', '뙤놈')
# ('corpus\\SmallTalk_Fword.txt', '뙨넘')
# ('corpus\\SmallTalk_Fword.txt', '뙨놈')
# ('corpus\\SmallTalk_Fword.txt', '뚜쟁')
# ('corpus\\SmallTalk_Fword.txt', '띠바')
# ('corpus\\SmallTalk_Fword.txt', '띠발')
# ('corpus\\SmallTalk_Fword.txt', '띠불')
# ('corpus\\SmallTalk_Fword.txt', '띠팔')
# ('corpus\\SmallTalk_Fword.txt', '메친넘')
# ('corpus\\SmallTalk_Fword.txt', '메친놈')
# ('corpus\\SmallTalk_Fword.txt', '미췬')
# ('corpus\\SmallTalk_Fword.txt', '미친')
# ('corpus\\SmallTalk_Fword.txt', '미친넘')
# ('corpus\\SmallTalk_Fword.txt', '미친년')
# ('corpus\\SmallTalk_Fword.txt', '미친놈')
# ('corpus\\SmallTalk_Fword.txt', '미친새끼')
# ('corpus\\SmallTalk_Fword.txt', '미친스까이')
# ('corpus\\SmallTalk_Fword.txt', '미틴')
# ('corpus\\SmallTalk_Fword.txt', '미틴넘')
# ('corpus\\SmallTalk_Fword.txt', '미틴년')
# ('corpus\\SmallTalk_Fword.txt', '미틴놈')
# ('corpus\\SmallTalk_Fword.txt', '바랄년')
# ('corpus\\SmallTalk_Fword.txt', '병자')
# ('corpus\\SmallTalk_Fword.txt', '뱅마')
# ('corpus\\SmallTalk_Fword.txt', '뱅신')
# ('corpus\\SmallTalk_Fword.txt', '벼엉신')
# ('corpus\\SmallTalk_Fword.txt', '병쉰')
# ('corpus\\SmallTalk_Fword.txt', '부랄')
# ('corpus\\SmallTalk_Fword.txt', '부럴')
# ('corpus\\SmallTalk_Fword.txt', '불알')
# ('corpus\\SmallTalk_Fword.txt', '불할')
# ('corpus\\SmallTalk_Fword.txt', '붕가')
# ('corpus\\SmallTalk_Fword.txt', '붙어먹')
# ('corpus\\SmallTalk_Fword.txt', '뷰웅')
# ('corpus\\SmallTalk_Fword.txt', '븅')
# ('corpus\\SmallTalk_Fword.txt', '븅신')
# ('corpus\\SmallTalk_Fword.txt', '빌어먹')
# ('corpus\\SmallTalk_Fword.txt', '빙시')
# ('corpus\\SmallTalk_Fword.txt', '빙신')
# ('corpus\\SmallTalk_Fword.txt', '빠굴')
# ('corpus\\SmallTalk_Fword.txt', '빠큐')
# ('corpus\\SmallTalk_Fword.txt', '뻐큐')
# ('corpus\\SmallTalk_Fword.txt', '뻑큐')
# ('corpus\\SmallTalk_Fword.txt', '뽁큐')
# ('corpus\\SmallTalk_Fword.txt', '상넘이')
# ('corpus\\SmallTalk_Fword.txt', '상놈을')
# ('corpus\\SmallTalk_Fword.txt', '상놈의')
# ('corpus\\SmallTalk_Fword.txt', '상놈이')
# ('corpus\\SmallTalk_Fword.txt', '새갸')
# ('corpus\\SmallTalk_Fword.txt', '새꺄')
# ('corpus\\SmallTalk_Fword.txt', '새새끼')
# ('corpus\\SmallTalk_Fword.txt', '새키')
# ('corpus\\SmallTalk_Fword.txt', '색끼')
# ('corpus\\SmallTalk_Fword.txt', '생쑈')
# ('corpus\\SmallTalk_Fword.txt', '세갸')
# ('corpus\\SmallTalk_Fword.txt', '세꺄')
# ('corpus\\SmallTalk_Fword.txt', '세끼')
# ('corpus\\SmallTalk_Fword.txt', '섹스')
# ('corpus\\SmallTalk_Fword.txt', '쇼하네')
# ('corpus\\SmallTalk_Fword.txt', '쉐')
# ('corpus\\SmallTalk_Fword.txt', '쉐기')
# ('corpus\\SmallTalk_Fword.txt', '쉐끼')
# ('corpus\\SmallTalk_Fword.txt', '쉐리')
# ('corpus\\SmallTalk_Fword.txt', '쉐에기')
# ('corpus\\SmallTalk_Fword.txt', '쉐키')
# ('corpus\\SmallTalk_Fword.txt', '쉑')
# ('corpus\\SmallTalk_Fword.txt', '쉣')
# ('corpus\\SmallTalk_Fword.txt', '쉨')
# ('corpus\\SmallTalk_Fword.txt', '쉬발')
# ('corpus\\SmallTalk_Fword.txt', '쉬밸')
# ('corpus\\SmallTalk_Fword.txt', '쉬벌')
# ('corpus\\SmallTalk_Fword.txt', '쉬뻘')
# ('corpus\\SmallTalk_Fword.txt', '쉬펄')
# ('corpus\\SmallTalk_Fword.txt', '쉽알')
# ('corpus\\SmallTalk_Fword.txt', '스패킹')
# ('corpus\\SmallTalk_Fword.txt', '스팽')
# ('corpus\\SmallTalk_Fword.txt', '시궁창')
# ('corpus\\SmallTalk_Fword.txt', '시끼')
# ('corpus\\SmallTalk_Fword.txt', '시댕')
# ('corpus\\SmallTalk_Fword.txt', '시뎅')
# ('corpus\\SmallTalk_Fword.txt', '시랄')
# ('corpus\\SmallTalk_Fword.txt', '시발')
# ('corpus\\SmallTalk_Fword.txt', '시벌')
# ('corpus\\SmallTalk_Fword.txt', '시부랄')
# ('corpus\\SmallTalk_Fword.txt', '시부럴')
# ('corpus\\SmallTalk_Fword.txt', '시부리')
# ('corpus\\SmallTalk_Fword.txt', '시불')
# ('corpus\\SmallTalk_Fword.txt', '시브랄')
# ('corpus\\SmallTalk_Fword.txt', '시팍')
# ('corpus\\SmallTalk_Fword.txt', '시팔')
# ('corpus\\SmallTalk_Fword.txt', '시펄')
# ('corpus\\SmallTalk_Fword.txt', '신발끈')
# ('corpus\\SmallTalk_Fword.txt', '심발끈')
# ('corpus\\SmallTalk_Fword.txt', '심탱')
# ('corpus\\SmallTalk_Fword.txt', '십8')
# ('corpus\\SmallTalk_Fword.txt', '십라')
# ('corpus\\SmallTalk_Fword.txt', '십새')
# ('corpus\\SmallTalk_Fword.txt', '십새끼')
# ('corpus\\SmallTalk_Fword.txt', '십세')
# ('corpus\\SmallTalk_Fword.txt', '십쉐')
# ('corpus\\SmallTalk_Fword.txt', '십쉐이')
# ('corpus\\SmallTalk_Fword.txt', '십스키')
# ('corpus\\SmallTalk_Fword.txt', '십쌔')
# ('corpus\\SmallTalk_Fword.txt', '십창')
# ('corpus\\SmallTalk_Fword.txt', '십탱')
# ('corpus\\SmallTalk_Fword.txt', '싶알')
# ('corpus\\SmallTalk_Fword.txt', '싸가지')
# ('corpus\\SmallTalk_Fword.txt', '싹아지')
# ('corpus\\SmallTalk_Fword.txt', '쌉년')
# ('corpus\\SmallTalk_Fword.txt', '쌍넘')
# ('corpus\\SmallTalk_Fword.txt', '쌍뇬')
# ('corpus\\SmallTalk_Fword.txt', '쌔끼')
# ('corpus\\SmallTalk_Fword.txt', '쌕')
# ('corpus\\SmallTalk_Fword.txt', '쌩쑈')
# ('corpus\\SmallTalk_Fword.txt', '쌴년')
# ('corpus\\SmallTalk_Fword.txt', '썅년')
# ('corpus\\SmallTalk_Fword.txt', '썅놈')
# ('corpus\\SmallTalk_Fword.txt', '썡쇼')
# ('corpus\\SmallTalk_Fword.txt', '써벌')
# ('corpus\\SmallTalk_Fword.txt', '썩을년')
# ('corpus\\SmallTalk_Fword.txt', '썩을놈')
# ('corpus\\SmallTalk_Fword.txt', '쎄꺄')
# ('corpus\\SmallTalk_Fword.txt', '쎄엑')
# ('corpus\\SmallTalk_Fword.txt', '쒸벌')
# ('corpus\\SmallTalk_Fword.txt', '쒸뻘')
# ('corpus\\SmallTalk_Fword.txt', '쒸팔')
# ('corpus\\SmallTalk_Fword.txt', '쒸펄')
# ('corpus\\SmallTalk_Fword.txt', '쓰바')
# ('corpus\\SmallTalk_Fword.txt', '쓰박')
# ('corpus\\SmallTalk_Fword.txt', '쓰발')
# ('corpus\\SmallTalk_Fword.txt', '쓰벌')
# ('corpus\\SmallTalk_Fword.txt', '쓰팔')
# ('corpus\\SmallTalk_Fword.txt', '씁새')
# ('corpus\\SmallTalk_Fword.txt', '씁얼')
# ('corpus\\SmallTalk_Fword.txt', '씌파')
# ('corpus\\SmallTalk_Fword.txt', '씨8')
# ('corpus\\SmallTalk_Fword.txt', '씨끼')
# ('corpus\\SmallTalk_Fword.txt', '씨댕')
# ('corpus\\SmallTalk_Fword.txt', '씨뎅')
# ('corpus\\SmallTalk_Fword.txt', '씨바')
# ('corpus\\SmallTalk_Fword.txt', '씨바랄')
# ('corpus\\SmallTalk_Fword.txt', '씨박')
# ('corpus\\SmallTalk_Fword.txt', '씨방')
# ('corpus\\SmallTalk_Fword.txt', '씨방새')
# ('corpus\\SmallTalk_Fword.txt', '씨방세')
# ('corpus\\SmallTalk_Fword.txt', '씨밸')
# ('corpus\\SmallTalk_Fword.txt', '씨뱅')
# ('corpus\\SmallTalk_Fword.txt', '씨벌')
# ('corpus\\SmallTalk_Fword.txt', '씨벨')
# ('corpus\\SmallTalk_Fword.txt', '씨봉')
# ('corpus\\SmallTalk_Fword.txt', '씨봉알')
# ('corpus\\SmallTalk_Fword.txt', '씨부랄')
# ('corpus\\SmallTalk_Fword.txt', '씨부럴')
# ('corpus\\SmallTalk_Fword.txt', '씨부렁')
# ('corpus\\SmallTalk_Fword.txt', '씨부리')
# ('corpus\\SmallTalk_Fword.txt', '씨불')
# ('corpus\\SmallTalk_Fword.txt', '씨붕')
# ('corpus\\SmallTalk_Fword.txt', '씨브랄')
# ('corpus\\SmallTalk_Fword.txt', '씨빠')
# ('corpus\\SmallTalk_Fword.txt', '씨빨')
# ('corpus\\SmallTalk_Fword.txt', '씨뽀랄')
# ('corpus\\SmallTalk_Fword.txt', '씨앙')
# ('corpus\\SmallTalk_Fword.txt', '씨파')
# ('corpus\\SmallTalk_Fword.txt', '씨팍')
# ('corpus\\SmallTalk_Fword.txt', '씨펄')
# ('corpus\\SmallTalk_Fword.txt', '씸년')
# ('corpus\\SmallTalk_Fword.txt', '씸뇬')
# ('corpus\\SmallTalk_Fword.txt', '씸새끼')
# ('corpus\\SmallTalk_Fword.txt', '씹같')
# ('corpus\\SmallTalk_Fword.txt', '씹년')
# ('corpus\\SmallTalk_Fword.txt', '씹뇬')
# ('corpus\\SmallTalk_Fword.txt', '씹보지')
# ('corpus\\SmallTalk_Fword.txt', '씹새')
# ('corpus\\SmallTalk_Fword.txt', '씹새기')
# ('corpus\\SmallTalk_Fword.txt', '씹새리')
# ('corpus\\SmallTalk_Fword.txt', '씹세')
# ('corpus\\SmallTalk_Fword.txt', '씹쉐')
# ('corpus\\SmallTalk_Fword.txt', '씹스키')
# ('corpus\\SmallTalk_Fword.txt', '씹쌔')
# ('corpus\\SmallTalk_Fword.txt', '씹이')
# ('corpus\\SmallTalk_Fword.txt', '씹자지')
# ('corpus\\SmallTalk_Fword.txt', '씹질')
# ('corpus\\SmallTalk_Fword.txt', '씹탱')
# ('corpus\\SmallTalk_Fword.txt', '씹퇭')
# ('corpus\\SmallTalk_Fword.txt', '씹팔')
# ('corpus\\SmallTalk_Fword.txt', '씹할')
# ('corpus\\SmallTalk_Fword.txt', '씹헐')
# ('corpus\\SmallTalk_Fword.txt', '아갈')
# ('corpus\\SmallTalk_Fword.txt', '아갈이')
# ('corpus\\SmallTalk_Fword.txt', '아갈통')
# ('corpus\\SmallTalk_Fword.txt', '아구창')
# ('corpus\\SmallTalk_Fword.txt', '아구통')
# ('corpus\\SmallTalk_Fword.txt', '아굴')
# ('corpus\\SmallTalk_Fword.txt', '얌마')
# ('corpus\\SmallTalk_Fword.txt', '양넘')
# ('corpus\\SmallTalk_Fword.txt', '양년')
# ('corpus\\SmallTalk_Fword.txt', '양놈')
# ('corpus\\SmallTalk_Fword.txt', '엄창')
# ('corpus\\SmallTalk_Fword.txt', '엠병')
# ('corpus\\SmallTalk_Fword.txt', '여물통')
# ('corpus\\SmallTalk_Fword.txt', '엿같')
# ('corpus\\SmallTalk_Fword.txt', '옘병')
# ('corpus\\SmallTalk_Fword.txt', '옘빙')
# ('corpus\\SmallTalk_Fword.txt', '오입')
# ('corpus\\SmallTalk_Fword.txt', '욤병')
# ('corpus\\SmallTalk_Fword.txt', '육갑')
# ('corpus\\SmallTalk_Fword.txt', '은년')
# ('corpus\\SmallTalk_Fword.txt', '을년')
# ('corpus\\SmallTalk_Fword.txt', '이년')
# ('corpus\\SmallTalk_Fword.txt', '이새끼')
# ('corpus\\SmallTalk_Fword.txt', '이새키')
# ('corpus\\SmallTalk_Fword.txt', '이스끼')
# ('corpus\\SmallTalk_Fword.txt', '이스키')
# ('corpus\\SmallTalk_Fword.txt', '임마')
# ('corpus\\SmallTalk_Fword.txt', '자슥')
# ('corpus\\SmallTalk_Fword.txt', '잡것')
# ('corpus\\SmallTalk_Fword.txt', '잡넘')
# ('corpus\\SmallTalk_Fword.txt', '잡년')
# ('corpus\\SmallTalk_Fword.txt', '잡놈')
# ('corpus\\SmallTalk_Fword.txt', '저년')
# ('corpus\\SmallTalk_Fword.txt', '저새끼')
# ('corpus\\SmallTalk_Fword.txt', '접년')
# ('corpus\\SmallTalk_Fword.txt', '젖밥')
# ('corpus\\SmallTalk_Fword.txt', '조까')
# ('corpus\\SmallTalk_Fword.txt', '조까치')
# ('corpus\\SmallTalk_Fword.txt', '조낸')
# ('corpus\\SmallTalk_Fword.txt', '조또')
# ('corpus\\SmallTalk_Fword.txt', '조랭')
# ('corpus\\SmallTalk_Fword.txt', '조빠')
# ('corpus\\SmallTalk_Fword.txt', '조쟁이')
# ('corpus\\SmallTalk_Fword.txt', '조지냐')
# ('corpus\\SmallTalk_Fword.txt', '조진다')
# ('corpus\\SmallTalk_Fword.txt', '조찐')
# ('corpus\\SmallTalk_Fword.txt', '조질래')
# ('corpus\\SmallTalk_Fword.txt', '존나게')
# ('corpus\\SmallTalk_Fword.txt', '존니')
# ('corpus\\SmallTalk_Fword.txt', '존만')
# ('corpus\\SmallTalk_Fword.txt', '존만한')
# ('corpus\\SmallTalk_Fword.txt', '좀물')
# ('corpus\\SmallTalk_Fword.txt', '좁년')
# ('corpus\\SmallTalk_Fword.txt', '좁밥')
# ('corpus\\SmallTalk_Fword.txt', '좃까')
# ('corpus\\SmallTalk_Fword.txt', '좃또')
# ('corpus\\SmallTalk_Fword.txt', '좃만')
# ('corpus\\SmallTalk_Fword.txt', '좃밥')
# ('corpus\\SmallTalk_Fword.txt', '좃이')
# ('corpus\\SmallTalk_Fword.txt', '좃찐')
# ('corpus\\SmallTalk_Fword.txt', '좆같')
# ('corpus\\SmallTalk_Fword.txt', '좆까')
# ('corpus\\SmallTalk_Fword.txt', '좆나')
# ('corpus\\SmallTalk_Fword.txt', '좆또')
# ('corpus\\SmallTalk_Fword.txt', '좆만')
# ('corpus\\SmallTalk_Fword.txt', '좆밥')
# ('corpus\\SmallTalk_Fword.txt', '좆이')
# ('corpus\\SmallTalk_Fword.txt', '좆찐')
# ('corpus\\SmallTalk_Fword.txt', '좇같')
# ('corpus\\SmallTalk_Fword.txt', '좇이')
# ('corpus\\SmallTalk_Fword.txt', '좌식')
# ('corpus\\SmallTalk_Fword.txt', '주글')
# ('corpus\\SmallTalk_Fword.txt', '주글래')
# ('corpus\\SmallTalk_Fword.txt', '주데이')
# ('corpus\\SmallTalk_Fword.txt', '주뎅')
# ('corpus\\SmallTalk_Fword.txt', '주뎅이')
# ('corpus\\SmallTalk_Fword.txt', '주둥아리')
# ('corpus\\SmallTalk_Fword.txt', '주둥이')
# ('corpus\\SmallTalk_Fword.txt', '주접')
# ('corpus\\SmallTalk_Fword.txt', '주접떨')
# ('corpus\\SmallTalk_Fword.txt', '죽고잡')
# ('corpus\\SmallTalk_Fword.txt', '죽을래')
# ('corpus\\SmallTalk_Fword.txt', '죽통')
# ('corpus\\SmallTalk_Fword.txt', '쥐랄')
# ('corpus\\SmallTalk_Fword.txt', '쥐롤')
# ('corpus\\SmallTalk_Fword.txt', '쥬디')
# ('corpus\\SmallTalk_Fword.txt', '지럴')
# ('corpus\\SmallTalk_Fword.txt', '지롤')
# ('corpus\\SmallTalk_Fword.txt', '지미랄')
# ('corpus\\SmallTalk_Fword.txt', '짜식')
# ('corpus\\SmallTalk_Fword.txt', '짜아식')
# ('corpus\\SmallTalk_Fword.txt', '쫍빱')
# ('corpus\\SmallTalk_Fword.txt', '찌랄')
# ('corpus\\SmallTalk_Fword.txt', '창녀')
# ('corpus\\SmallTalk_Fword.txt', '캐년')
# ('corpus\\SmallTalk_Fword.txt', '캐놈')
# ('corpus\\SmallTalk_Fword.txt', '캐스끼')
# ('corpus\\SmallTalk_Fword.txt', '캐스키')
# ('corpus\\SmallTalk_Fword.txt', '캐시키')
# ('corpus\\SmallTalk_Fword.txt', '탱구')
# ('corpus\\SmallTalk_Fword.txt', '팔럼')
# ('corpus\\SmallTalk_Fword.txt', '퍽큐')
# ('corpus\\SmallTalk_Fword.txt', '호로')
# ('corpus\\SmallTalk_Fword.txt', '호로놈')
# ('corpus\\SmallTalk_Fword.txt', '호로새끼')
# ('corpus\\SmallTalk_Fword.txt', '호로색')
# ('corpus\\SmallTalk_Fword.txt', '호로쉑')
# ('corpus\\SmallTalk_Fword.txt', '호로스까이')
# ('corpus\\SmallTalk_Fword.txt', '호로스키')
# ('corpus\\SmallTalk_Fword.txt', '후라들')
# ('corpus\\SmallTalk_Fword.txt', '후래자식')
# ('corpus\\SmallTalk_Fword.txt', '후레')
# ('corpus\\SmallTalk_Fword.txt', '후뢰')
# ('corpus\\SmallTalk_RUThere.txt', '야')
# ('corpus\\SmallTalk_RUThere.txt', '저기요')
# ('corpus\\SmallTalk_RUThere.txt', '님')
# ('corpus\\SmallTalk_RUThere.txt', '님아')
# ('corpus\\SmallTalk_RUThere.txt', '다시 한번 말해봐')
# ('corpus\\SmallTalk_RUThere.txt', '야야')
# ('corpus\\SmallTalk_Thanks.txt', '잘했어')
# ('corpus\\SmallTalk_Thanks.txt', '올~')

# %%
mecab = Mecab()
mecab.pos('20도로 맞춰줘')
# Out:
# [('20', 'SN'), ('도', 'NNBC'), ('로', 'JKB'), ('맞춰', 'VV+EC'), ('줘', 'VX+EC')]
